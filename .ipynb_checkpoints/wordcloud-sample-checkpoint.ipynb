# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image
import numpy as np
import jieba

mask = np.array(Image.open('cloud.jpg'))

with open("nkustnews.txt", "r", encoding="utf-8") as fp:
    data = fp.read()
data = data.translate({ord(c):None for c in list("(),.“”\n")})
#jieba.load_userdict("userdict.txt")
words = jieba.cut(data)
words = [w for w in words]
print(words)
words = ",".join(words)
wordcloud = WordCloud(background_color="white",
                      width=1000, height=860, 
                      margin=2, font_path="simhei.ttf", 
                      mask=mask).generate(words)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
# Out:
# ['高科大', '主辦', '第十七', '屆', '全國', '高中', '職太陽能', '模型', '車競賽', ' ', '疫情', '復', '甦', '再戰', '澳洲', '國際賽', '奪冠', '高科大', '營建系', '義築', '團隊', ' ', '重現', '原民傳', '統芋', '頭窯', '文化', '高科大', '主辦', '智慧', '機器', '人大', '賽', '十年', '有', '成', ' ', ' ', '今年', '國際賽', '成績', '亮眼', '金屬', '材料', '暨', '加工', '設備展', ' ', ' ', '高科大', '發表', '創新', '模具', '技術', '挺', '高雄', '青創', ' ', '高科大', '辦', '市集', '「', '遛', '遛', 'chill', '」', '嗨', '翻駁', '二特區', '高科大', '研發', '魚鱗', '珍珠奶茶', '大獲', '好評', ' ', '農漁產品', '加值', '兼顧', '創新', '與', '永續', '高科大', '預見', '未來', '人才', ' ', '高教', '深耕', '論壇', '邀產', '官學', '、', '氣候', '少女', '對話', '「', '鹽', '埕', '世界', '盃', '奶茶', '節', '」', '10', '月', '1', '日開', '跑', ' ', ' ', '高科大', '串聯鹽', '埕', '商家', '邁', '大步', '玉', '荷包', '酸', '啤酒', '勇奪', 'WBA', '世界', '最佳', '啤酒', '大獎', ' ', ' ', '高科大', '與', '自由人', '釀造', '同賀', '全國首', '創師', '資生', '結合', '水域', '安全', '課程', ' ', ' ', '「', '未來', '老師們', '」', '直呼', '太', '受用', '高科大', '攜手', '美商', '達爾', '科技', '簽署', 'MOU', ' ', '強化產學', '合作', '培育', '半導體', '人才', '高科大', '澎湖', '縣府', '守護', '海洋', ' ', '清除', '海底', '覆網', '4', '年', '累積', '10', '萬', '公斤', '廢具', '高科大', '清除', '海底', '覆網', '成果', '發表會', ' ', ' ', '9', '/', '20', '澎湖', '馬', '公機場', '盛大', '登場', '企業', '加入', '淨海', '行列', '！', ' ', '高科大', '團隊', '率', '10', '潛水員', '一小', '時清', '55', '公斤', '垃圾', '台灣', '23%', '河川', '中重度', '污染', ' ', '高科大', 'USR', '聯手', '富邦', '人壽以', '行動', '淨溪', '高科大', '毅志樓', '宿舍', '落成', '啟用', ' ', ' ', '軒嵐諾', '壓境', '新生', '入宿', '正常', '舉行', '國際', '創意', '競賽', '有', '焦點', ' ', ' ', '高科大', '創創', '中心', '環保瓶', '蓋', '超吸睛', '高科大', '響應', '2030', '雙語', '國家', '政策', ' ', '辦國', '小英語', '營培養', '海洋', '永續', '觀念', '台灣', '漁貨', '打國際賽', ' ', ' ', '高科大', '前進', '日本', '國際', '水產展', '國立', '大專', '校院', '之冠', '！', '高科大', '勇奪', '2022', '台灣永續', '行動獎', '3', '金', '1', '銀好', '成績', '高科大', '主辦', '智慧', '跨域', '人才', '培育', '計畫', ' ', '7', '跨校', '產學', '聯盟', '成果', '亮眼', '青少年', '開放', '水域', '安全', '教育', ' ', ' ', '高雄市', '永安', '烏林', '投', '海域', '登場', '高科大', '義築', '團隊', '親手', '打造', '芋頭', '窯', ' ', ' ', '傳承', '原住民', '食農', '文化', '高科大', '首屆', '師資生', '投入', '教育史', '懷哲計畫', ' ', ' ', '深刻', '體會', '教育', '服務', '意涵', '高科大', '連', '17', '年', '舉辦', '高中', '職太陽', '能車', '競賽', ' ', '基隆', '二信奪', '回冠', '軍首屆', '108', '課綱', '大', '一', '新生', '入學', ' ', ' ', '高科大', '與', '招生', '專業化', '總', '辦首', '開座', '談', '高科大', 'USR', '前進', '偏鄉', ' ', '行銷', '左鎮', '農特產', '品號', '召輕', '旅行', '覆網', '清除', '培訓', '課', '水下', '實戰', '演練', ' ', '14', '名學員', '加入', '海洋', '守護', '行動', '台灣', '農產', '加工', '創意', '再', '升級', ' ', '高科大', '產學', '合作', '打造', '新商機', '高科', '企管系', '與', '尊邑', '建設', '簽署', 'MOU', ' ', ' ', '互享', '產學', '資源', '共', '創雙贏', '搭載', '微軟', 'Azure', '雲端', '服務', 'AI', '自駕車', ' ', ' ', '高科大', '跨學院', '啟動', '協作', '開發', '高科大', '先進', '金屬', '成型', '與', '材料', '技術', '扮要', '角', ' ', ' ', '與', '高', '市府', '共推', '航太產業', '鏈', '高科大', '衛武營', '簽署', 'MOU', ' ', '合作', '推展', '南部', '美感', '教育', '及', '展演', '活動菲國', '友人', '榮任', '部長', ' ', '台菲學術', '交流', '盼持續', '深化', '高科大', '科工', '館', '簽署', 'Ｍ', 'Ｏ', 'Ｕ', '\u3000', '實驗室', '退役', '儀器', '將成', '收藏', '工藝品', '高科大', '出版', '首份', '永續', '報告', '書', ' ', '目標', '2028', '年達成', '碳', '中', '和', '守護', '海洋', '拒絕', '「', '網', '」', '來', ' ', '高科大', '與', '澎湖', '縣府號', '召志工', '一起', '清除', '覆網', '撒部', '・', '噶照', '用', '創作', '傳達海', '的', '訊息', ' ', '建工', '藝文個展', '浪漫', '登場', '高科大', '上進', '夫妻', '檔', '假日', '進修', ' ', '畢業', '雙喜', '臨門', '迎二寶', '高科大', '環境', '教育', '推廣攜手', 'USR', ' ', '邀企業', '政府', '一起', '翻轉', '在', '地', '高科大', '導入', '智慧', '車聯網', ' ', '助', '小琉球', '規劃', '低', '碳', '旅行', '文創系', '畢展', '放視', '大賞', '登場', ' ', '溺水', '世代', '躍出', '水面', '追夢', '高科大', '研發', '太陽能', '電動', '車首', '亮相', ' ', '將啟', '程', '多次', '環島試', '跑', '高科大', '多項', '作品', '入圍', '金點', '新秀', ' ', '新一代', '設計展', '即將', '揭曉', '高科大', '專業', '技術', '投入', '漁電', '共生', ' ', '高', '市府', '攜手產', '官學', '打造', '綠電', '城市', '校務', '諮', '詢委員', '參訪', '高科大', ' ', ' ', '校長', '：', '啟動', '新', '一階段', '系', '所', '改質', '躍升', '計畫', '知名', '大廠', '搶', '才', '釋千餘', '職缺', ' ', ' ', '高科大', '徵才', '博覽會', '盛大', '登場', '培育', '地方', '跨域', '人才', ' ', '高科大', '簽署', '教育部', 'USR', '共培協議', '書', '高科大', '跨域', '人才', '國際爭', '光', '\u3000', '四創', '教育', '強化', '學生', '職場', '競爭力', '程式', '教學 ...
